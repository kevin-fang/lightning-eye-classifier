# %%
from sklearn.svm import SVC
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("PGP-eyecolor.csv", names=columns)
data.columns = columns
data.head()
# Out:
#                                                                                                                                                      left  \
# Participant Left Eye Right Eye 2.3 — Left Eye Color - Text Description 2.4 — Right Eye Color - Text Description NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN
# hu826751    11       11        greyish blue                            greyish blue                             NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN
# huDDCF88    1        1         blue                                    same                                     NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN
# hu3DC5EA    15       15        light brown                             light brown                              NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN
# hu008567    7        7         very blue with darker blue outside ring very blue with darker blue outside ring  NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN
#
# ...
